# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51939/ADM_27/blob/main/ADM_2303A51939.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
s=pd.Series([12,3,4,5,6])
print(s)
# Out:
# 0    12
# 1     3
# 2     4
# 3     5
# 4     6
# dtype: int64

# %%
ds1 = pd.Series([2,4,1,66,9])
ds2 = pd.Series([9,0,7,4,6])
print("sum of Series element")
ds = ds1 + ds2
print(ds)
# Out:
# sum of Series element
# 0    11
# 1     4
# 2     8
# 3    70
# 4    15
# dtype: int64

# %%
ds1 = pd.Series([2,4,1,66,9])
ds2 = pd.Series([9,0,7,4,6])
print("product od Series element")
ds = ds1 * ds2
print(ds)
# Out:
# product od Series element
# 0     18
# 1      0
# 2      7
# 3    264
# 4     54
# dtype: int64

# %%
ds1 = pd.Series([2,4,1,66,9])
ds2 = pd.Series([9,0,7,4,6])
print("diference of Series element")
ds = ds1 - ds2
print(ds)
# Out:
# diference of Series element
# 0    -7
# 1     4
# 2    -6
# 3    62
# 4     3
# dtype: int64

# %%
import pandas as pd
from google.colab import files
my_path = '/content/banklist.csv'
data = pd.read_csv(my_path)
data.head()
# Out:
#                                   Bank Name          City  ST   CERT  \
# 0  Banks of Wisconsin d/b/a Bank of Kenosha       Kenosha  WI  35386
# 1                      Central Arizona Bank    Scottsdale  AZ  34527
# 2                              Sunrise Bank      Valdosta  GA  58185
# 3                     Pisgah Community Bank     Asheville  NC  58701
# 4                       Douglas County Bank  Douglasville  GA  21649
#
#    Acquiring Institution Closing Date Updated Date
# 0  North Shore Bank, FSB    31-May-13    31-May-13
# 1     Western State Bank    14-May-13    20-May-13
# 2           Synovus Bank    10-May-13    21-May-13
# 3     Capital Bank, N.A.    10-May-13    14-May-13
# 4    Hamilton State Bank    26-Apr-13    16-May-13

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
data = pd.read_csv('banklist.csv')
data.head()
# Out:
#      <input type="file" id="files-3197a2ce-6861-4339-9eb6-6d20c58025f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3197a2ce-6861-4339-9eb6-6d20c58025f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
data = pd.read_csv('banklist.csv')
print(data.isnull().sum())
# Out:
#      <input type="file" id="files-4dec620b-fb7e-4771-b711-d8d5ca2ca4bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4dec620b-fb7e-4771-b711-d8d5ca2ca4bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
data = pd.read_csv('titanic.csv')
print(data.isnull().sum())
# Out:
#      <input type="file" id="files-79193a5f-7b02-48f4-b029-3fd4cb1d7382" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79193a5f-7b02-48f4-b029-3fd4cb1d7382">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
data = pd.read_csv('titanic.csv')
print(data.isnull().sum())
data['Age'].fillna(data['Age'].mean(), inplace=True)
print(data.isnull().sum())
# Out:
#      <input type="file" id="files-b4af6d1f-e73d-4b6c-84a2-c2f7150cd4fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4af6d1f-e73d-4b6c-84a2-c2f7150cd4fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
