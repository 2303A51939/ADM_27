# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51939/ADM_27/blob/main/ADM_2303A51939.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 1, 2, 3, 4, 5])
ypoints = np.array([3,8,1,10,5,7])
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 1, 2, 3, 4, 5])
ypoints = np.array([3,8,1,10,5,7])
ypoints = np.array([2,8,6,9,4,7])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'royalblue', mfc = 'yellow')
plt.plot(ypoints, linestyle = ':')
plt.plot(ypoints, color ='r')
plt.plot(ypoints, linewidth = '20.5')
plt.plot(xpoints,ypoints,'o:b')
plt.show()
plt.plot(xpoints,ypoints,'o:b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 50, 1, 105, 7])
plt.plot(ypoints, marker='o', ms=20, mec='royalblue', mfc='yellow')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 5])
ypoints = np.array([0,206])

plt.plot(xpoints, ypoints, 'o:k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
x2=np.array([0,1,2,3])
y2=np.array([10,1,8,3])
plt.plot(x1,y1,x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])

plt.bar(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
plt.grid()

plt.grid(axis='x')

plt.grid(axis='y')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x1,y1)
x2=np.array([0,1,2,3])
y2=np.array([10,1,6,8])
plt.subplot(2,1,2)
plt.plot(x2,y2)
plt.show()

# %%
y = np.array([35,25,25,15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels,explode=myexplode)
plt.show()
